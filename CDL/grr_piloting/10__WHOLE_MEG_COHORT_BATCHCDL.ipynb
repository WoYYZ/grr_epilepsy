# %%
from scipy.io import loadmat
from scipy.io import savemat 
import os
import numpy as np
import matplotlib.pyplot as plt
from alphacsc import GreedyCDL
from alphacsc.utils import split_signal
from scipy import signal
from scipy.signal import butter, filtfilt
from matplotlib import gridspec
import time
from alphacsc import BatchCDL
from pathlib import Path

def butter_lowpass(data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low')
    y = filtfilt(b, a, data)
    return y

def butter_highpass(data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='high')
    y = filtfilt(b, a, data)
    return y

# %%
# !ls /mnt/megshare/Development/Sheng/__dump/20241126_aes_poster_figures/

#################################################################
## all parameters are set here
#################################################################
ori_fs             = 1000 # Original sampling rate (Hz)
decimate           = 10   # dec factor for analysis data
HI_PASS            = 1    #Hz 
LOW_PASS           = 30   #Hz
fs                 = ori_fs // decimate  # decimated signal fs
n_atoms            = 30
ATOM_DURATION      = 3    # seconds
SPLIT_BLOCKS       = 8    # Spliting a long resting into x blocks
N_JOBS             = 80   # cdl jobs
NORMALIZE          = True # normalize the parcel time series before CDL

MAT_FILE_WRITEOUT  = Path('/mnt/megshare/Development/Sheng/__dump/20241126_aes_poster_figures/')
MAT_FILE_WRITEOUT  = MAT_FILE_WRITEOUT / 'WHOLE_COHORT_ATOMS_30x3s_1-30Hz'
if not MAT_FILE_WRITEOUT.exists():
    MAT_FILE_WRITEOUT.mkdir()


SUBJ_DIR  = Path('/data/sheng/MEG_source_data/')
SUBJS     = [d.name for d in SUBJ_DIR.iterdir() if d.is_dir() and d.name.startswith('case_')]

if not MAT_FILE_WRITEOUT.exists():
    MAT_FILE_WRITEOUT.mkdir(parent=True)
# Out:
# __old				     tmp
# png_WHOLE_COHORT_ATOMS_30x3s_1-30Hz  WHOLE_COHORT_ATOMS_30x3s_1-30Hz
# subjects.txt			     WHOLE_COHORT_CROSSPY_FEATURES

# %%
t1 = time.time()
# for all subjects ##############################################################################
for i, subj in enumerate(SUBJS):
    SETS  = os.listdir(SUBJ_DIR / subj)
    
    t11=time.time()
    # for all spont sessions of the subj ####################
    for j, iSet in enumerate(SETS): 
                        
        subjPath = Path(SUBJ_DIR / subj / iSet / 'parcel_ts')
        filePath = list(subjPath.glob("*.npy"))[0]       
        
        #filePath = SUBJ_DIR / subj / iSet
        parcelTS     = np.load(filePath) # data: channels x samples
        PARC_N       = parcelTS.shape[0]
        SAMPLE_N     = signal.decimate(parcelTS[0], decimate).shape[0]
        bpTS         = np.zeros([PARC_N, SAMPLE_N])

        # band-pass the data, and decimate if need be #######################
        for iPARC in np.arange(0,PARC_N):
            aParcelTS            = parcelTS[iPARC]    
            lowpass_data         = butter_lowpass(aParcelTS, LOW_PASS, ori_fs)
            highpass_data        = butter_highpass(lowpass_data, HI_PASS, ori_fs)
            bpTS[iPARC, :]       = signal.decimate(highpass_data, decimate)
            if NORMALIZE:            
                iMEAN            = np.mean(bpTS[iPARC, :])
                iSTD             = np.std(bpTS[iPARC, ])            
                bpTS[iPARC,]     = (bpTS[iPARC, :]- iMEAN) / iSTD            

        del lowpass_data, highpass_data
        print('Band-pass done, now fitting: '+subj+ '-' + iSet + '...')


        # Split a long trial into x blocks
        split_parcTS = split_signal(bpTS[None], SPLIT_BLOCKS)

        # Define the shape of the dictionary
        n_times_atom = int(round(fs * ATOM_DURATION)) 
        print('Data shape:', split_parcTS.shape, '; N of Atoms: ',  n_atoms, '; Sample per atom: ', n_times_atom)


        cdl = BatchCDL(
            # Shape of the dictionary
            n_atoms=n_atoms,
            n_times_atom=n_times_atom,
            # Request a rank1 dictionary with unit norm temporal and spatial maps
            rank1=True, uv_constraint='separate',
            # Initialize the dictionary with random chunk from the data
            D_init='chunk',
            # rescale the regularization parameter to be 20% of lambda_max
            lmbd_max="scaled", reg=.2,
            # Number of iteration for the alternate minimization and cvg threshold
            n_iter=100, eps=1e-4,
            # solver for the z-step
            solver_z="lgcd", solver_z_kwargs={'tol': 1e-2, 'max_iter': 1000},
            # solver for the d-step
            solver_d='alternate_adaptive', solver_d_kwargs={'max_iter': 300},
            # Technical parameters
            verbose=1, random_state=0, n_jobs=N_JOBS)


        ######################################### FIT IT   
        cdl.fit(split_parcTS)
        del split_parcTS   
        ######################################### FIT IT   

        u_hat = cdl.u_hat_ # spatial
        v_hat = cdl.v_hat_ # temporal
        z_hat = cdl.z_hat_ # scores        
       
        # Output name set to 'case_xxxx_y_setzz_...'  ======================================
        
        SUBJ = filePath.parent.parent.parent.stem
        iSet  = filePath.parent.parent.stem
        
        if len(SUBJ) == 9: 
            SUBJ = SUBJ + '_1'
        SET   = 'set' + (f"{int(iSet[3:]):02d}")        
        
        FILENAME = (SUBJ + '_' + SET + '_BB_' + str(HI_PASS) + 
                    '-' + str(LOW_PASS) + 'Hz_' + str(n_atoms) + 
                    '_Atoms_' + str(ATOM_DURATION) + '(s)'+ '_NormParcTS(' + str(NORMALIZE)+ ').mat')
        MAT_FILE = MAT_FILE_WRITEOUT / FILENAME
        
        savemat(MAT_FILE, {"u_hat": u_hat, "v_hat": v_hat, 'z_hat': z_hat, 'fs': fs})
        print('\tWriting: ' + FILENAME)  
        t12=time.time()
        print('\tTime spent:', round((t12-t11)/60,1), ' mins.' )



t2 = time.time()    
print('\nN of atoms: ', n_atoms, ', Num of Jobs: ', N_JOBS)
print('Low: ', LOW_PASS, 'Hz, High:', HI_PASS, 'Hz')
print(f"Finished at: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(t2))}")
print('Total time spent:', round((t2-t1)/60,1), ' mins.' )
# Out:
# Band-pass done, now fitting: case_0307-set1...
# Data shape: (8, 200, 7625) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 7.812e-05, 8.515e-05
# [BatchCDL] Fit in 772.1s
# 	Writing: case_0307_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.0  mins.
# Band-pass done, now fitting: case_0307-set2...
# Data shape: (8, 200, 7475) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 6.718e-05, 9.471e-05
# [BatchCDL] Fit in 1166.7s
# 	Writing: case_0307_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 32.6  mins.
# Band-pass done, now fitting: case_0307-set3...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# /home/sheng/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# .......
# [BatchCDL] Converged after 21 iteration, (dz, du) = 4.918e-05, 8.149e-05
# [BatchCDL] Fit in 1105.0s
# 	Writing: case_0307_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 51.2  mins.
# Band-pass done, now fitting: case_0307-set4...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ...................
# [BatchCDL] Converged after 19 iteration, (dz, du) = 3.742e-05, 8.307e-05
# [BatchCDL] Fit in 1036.9s
# 	Writing: case_0307_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 68.6  mins.
# Band-pass done, now fitting: case_0307-set5...
# Data shape: (8, 200, 7850) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 4.909e-05, 8.768e-05
# [BatchCDL] Fit in 998.6s
# 	Writing: case_0307_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 85.4  mins.
# Band-pass done, now fitting: case_0307-set6...
# Data shape: (8, 200, 7637) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 7.205e-05, 9.012e-05
# [BatchCDL] Fit in 700.2s
# 	Writing: case_0307_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 97.2  mins.
# Band-pass done, now fitting: case_0307-set7...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 4.610e-05, 8.012e-05
# [BatchCDL] Fit in 931.2s
# 	Writing: case_0307_1_set07_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 112.8  mins.
# Band-pass done, now fitting: case_0307-set8...
# Data shape: (8, 200, 7650) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 7.113e-05, 9.711e-05
# [BatchCDL] Fit in 886.3s
# 	Writing: case_0307_1_set08_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 127.8  mins.
# Band-pass done, now fitting: case_0307-set9...
# Data shape: (8, 200, 7750) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 5.743e-05, 8.651e-05
# [BatchCDL] Fit in 916.4s
# 	Writing: case_0307_1_set09_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 143.2  mins.
# Band-pass done, now fitting: case_0307-set10...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 6.969e-05, 8.868e-05
# [BatchCDL] Fit in 606.4s
# 	Writing: case_0307_1_set10_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 153.4  mins.
# Band-pass done, now fitting: case_0307-set11...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# .......
# [BatchCDL] Converged after 7 iteration, (dz, du) = 6.865e-05, 8.894e-05
# [BatchCDL] Fit in 391.2s
# 	Writing: case_0307_1_set11_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 160.1  mins.
# Band-pass done, now fitting: case_0332-set1...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# .......
# [BatchCDL] Converged after 7 iteration, (dz, du) = 8.420e-05, 8.714e-05
# [BatchCDL] Fit in 436.6s
# 	Writing: case_0332_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 7.4  mins.
# Band-pass done, now fitting: case_0332-set2...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ..........
# [BatchCDL] Converged after 10 iteration, (dz, du) = 6.228e-05, 6.546e-05
# [BatchCDL] Fit in 586.3s
# 	Writing: case_0332_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.3  mins.
# Band-pass done, now fitting: case_0303-set1...
# Data shape: (8, 200, 7837) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 9.513e-05, 9.804e-05
# [BatchCDL] Fit in 867.3s
# 	Writing: case_0303_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 14.6  mins.
# Band-pass done, now fitting: case_0303-set3...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 5.921e-05, 8.598e-05
# [BatchCDL] Fit in 863.1s
# 	Writing: case_0303_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 29.1  mins.
# Band-pass done, now fitting: case_0340-set1...
# Data shape: (8, 200, 8012) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 4.911e-05, 9.589e-05
# [BatchCDL] Fit in 774.9s
# 	Writing: case_0340_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.1  mins.
# Band-pass done, now fitting: case_0340-set2...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 6.057e-05, 8.410e-05
# [BatchCDL] Fit in 831.4s
# 	Writing: case_0340_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 27.1  mins.
# Band-pass done, now fitting: case_0340-set4...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 8.229e-05, 9.618e-05
# [BatchCDL] Fit in 955.5s
# 	Writing: case_0340_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 43.1  mins.
# Band-pass done, now fitting: case_0440-set1...
# Data shape: (8, 200, 8225) ; N of Atoms:  30 ; Sample per atom:  300
# ........
# [BatchCDL] Converged after 8 iteration, (dz, du) = 7.800e-05, 9.537e-05
# [BatchCDL] Fit in 619.2s
# 	Writing: case_0440_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.5  mins.
# Band-pass done, now fitting: case_0440-set2...
# Data shape: (8, 200, 7825) ; N of Atoms:  30 ; Sample per atom:  300
# ......
# [BatchCDL] Converged after 6 iteration, (dz, du) = 7.164e-05, 9.346e-05
# [BatchCDL] Fit in 530.8s
# 	Writing: case_0440_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 19.5  mins.
# Band-pass done, now fitting: case_0442-set1...
# Data shape: (8, 200, 8262) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 5.969e-05, 9.402e-05
# [BatchCDL] Fit in 672.7s
# 	Writing: case_0442_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 11.4  mins.
# Band-pass done, now fitting: case_0442-set2...
# Data shape: (8, 200, 7750) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 5.075e-05, 7.516e-05
# [BatchCDL] Fit in 976.0s
# 	Writing: case_0442_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 27.8  mins.
# Band-pass done, now fitting: case_0441-set1...
# Data shape: (8, 200, 7962) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 6.929e-05, 8.208e-05
# [BatchCDL] Fit in 1034.7s
# 	Writing: case_0441_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.4  mins.
# Band-pass done, now fitting: case_0441-set2...
# Data shape: (8, 200, 8400) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 6.187e-05, 8.427e-05
# [BatchCDL] Fit in 839.0s
# 	Writing: case_0441_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 31.5  mins.
# Band-pass done, now fitting: case_0321-set1...
# Data shape: (8, 200, 7375) ; N of Atoms:  30 ; Sample per atom:  300
# ...................
# [BatchCDL] Converged after 19 iteration, (dz, du) = 4.428e-05, 9.075e-05
# [BatchCDL] Fit in 1094.4s
# 	Writing: case_0321_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 18.4  mins.
# Band-pass done, now fitting: case_0321-set2...
# Data shape: (8, 200, 7500) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 6.507e-05, 8.125e-05
# [BatchCDL] Fit in 694.1s
# 	Writing: case_0321_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 30.1  mins.
# Band-pass done, now fitting: case_0345-set1...
# Data shape: (8, 200, 7562) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 6.707e-05, 9.545e-05
# [BatchCDL] Fit in 607.7s
# 	Writing: case_0345_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.3  mins.
# Band-pass done, now fitting: case_0345-set2...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# .....
# [BatchCDL] Converged after 5 iteration, (dz, du) = 3.689e-05, 4.483e-05
# [BatchCDL] Fit in 272.4s
# 	Writing: case_0345_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.0  mins.
# Band-pass done, now fitting: case_0345-set3...
# Data shape: (8, 200, 7937) ; N of Atoms:  30 ; Sample per atom:  300
# ........
# [BatchCDL] Converged after 8 iteration, (dz, du) = 3.839e-05, 5.645e-05
# [BatchCDL] Fit in 505.7s
# 	Writing: case_0345_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 23.5  mins.
# Band-pass done, now fitting: case_0345-set4...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 6.631e-05, 9.778e-05
# [BatchCDL] Fit in 692.9s
# 	Writing: case_0345_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 35.2  mins.
# Band-pass done, now fitting: case_0345-set5...
# Data shape: (8, 200, 7562) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 5.444e-05, 8.090e-05
# [BatchCDL] Fit in 956.4s
# 	Writing: case_0345_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 51.3  mins.
# Band-pass done, now fitting: case_0345-set6...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 4.134e-05, 5.305e-05
# [BatchCDL] Fit in 1116.3s
# 	Writing: case_0345_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 70.1  mins.
# Band-pass done, now fitting: case_0345-set7...
# Data shape: (8, 200, 7137) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 4.502e-05, 7.068e-05
# [BatchCDL] Fit in 645.7s
# 	Writing: case_0345_1_set07_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 81.0  mins.
# Band-pass done, now fitting: case_0297-set1...
# Data shape: (8, 200, 6362) ; N of Atoms:  30 ; Sample per atom:  300
# .......................
# [BatchCDL] Converged after 23 iteration, (dz, du) = 4.820e-05, 9.143e-05
# [BatchCDL] Fit in 1599.5s
# 	Writing: case_0297_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 26.8  mins.
# Band-pass done, now fitting: case_0297-set2...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 6.497e-05, 8.986e-05
# [BatchCDL] Fit in 945.6s
# 	Writing: case_0297_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 42.7  mins.
# Band-pass done, now fitting: case_0335-set1...
# Data shape: (8, 200, 7675) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 5.958e-05, 7.362e-05
# [BatchCDL] Fit in 897.7s
# 	Writing: case_0335_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.1  mins.
# Band-pass done, now fitting: case_0335-set2...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ....
# [BatchCDL] Converged after 4 iteration, (dz, du) = 7.973e-05, 9.585e-05
# [BatchCDL] Fit in 222.7s
# 	Writing: case_0335_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 19.0  mins.
# Band-pass done, now fitting: case_0335-set5...
# Data shape: (8, 200, 7337) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 7.679e-05, 7.734e-05
# [BatchCDL] Fit in 642.6s
# 	Writing: case_0335_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 29.8  mins.
# Band-pass done, now fitting: case_0335-set6...
# Data shape: (8, 200, 7375) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 6.639e-05, 8.836e-05
# [BatchCDL] Fit in 885.1s
# 	Writing: case_0335_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 44.7  mins.
# Band-pass done, now fitting: case_0335-set7...
# Data shape: (8, 200, 7937) ; N of Atoms:  30 ; Sample per atom:  300
# .....
# [BatchCDL] Converged after 5 iteration, (dz, du) = 2.060e-05, 1.680e-05
# [BatchCDL] Fit in 420.1s
# 	Writing: case_0335_1_set07_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 51.9  mins.
# Band-pass done, now fitting: case_0443-set2...
# Data shape: (8, 200, 8437) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 9.150e-05, 9.369e-05
# [BatchCDL] Fit in 716.4s
# 	Writing: case_0443_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.1  mins.
# Band-pass done, now fitting: case_0443-set3...
# Data shape: (8, 200, 7600) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.161e-05, 9.507e-05
# [BatchCDL] Fit in 830.6s
# 	Writing: case_0443_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 26.1  mins.
# Band-pass done, now fitting: case_0237-set1...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 8.264e-05, 9.877e-05
# [BatchCDL] Fit in 840.3s
# 	Writing: case_0237_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 14.2  mins.
# Band-pass done, now fitting: case_0237-set2...
# Data shape: (8, 200, 7537) ; N of Atoms:  30 ; Sample per atom:  300
# ......................
# [BatchCDL] Converged after 22 iteration, (dz, du) = 4.709e-05, 9.609e-05
# [BatchCDL] Fit in 1214.6s
# 	Writing: case_0237_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 34.6  mins.
# Band-pass done, now fitting: case_0336-set1...
# Data shape: (8, 200, 7562) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 7.243e-05, 9.035e-05
# [BatchCDL] Fit in 892.3s
# 	Writing: case_0336_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.0  mins.
# Band-pass done, now fitting: case_0336-set2...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 6.200e-05, 8.913e-05
# [BatchCDL] Fit in 751.2s
# 	Writing: case_0336_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 27.7  mins.
# Band-pass done, now fitting: case_0336-set3...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ........................
# [BatchCDL] Converged after 24 iteration, (dz, du) = 7.119e-05, 9.965e-05
# [BatchCDL] Fit in 1352.3s
# 	Writing: case_0336_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 50.4  mins.
# Band-pass done, now fitting: case_0336-set4...
# Data shape: (8, 200, 7662) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.262e-05, 8.137e-05
# [BatchCDL] Fit in 811.7s
# 	Writing: case_0336_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 64.1  mins.
# Band-pass done, now fitting: case_0336-set5...
# Data shape: (8, 200, 8900) ; N of Atoms:  30 ; Sample per atom:  300
# .......................
# [BatchCDL] Converged after 23 iteration, (dz, du) = 3.490e-05, 5.999e-05
# [BatchCDL] Fit in 1397.6s
# 	Writing: case_0336_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 87.5  mins.
# Band-pass done, now fitting: case_0336-set6...
# Data shape: (8, 200, 7387) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 7.672e-05, 8.699e-05
# [BatchCDL] Fit in 737.5s
# 	Writing: case_0336_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 100.0  mins.
# Band-pass done, now fitting: case_0356-set1...
# Data shape: (8, 200, 7925) ; N of Atoms:  30 ; Sample per atom:  300
# .....
# [BatchCDL] Converged after 5 iteration, (dz, du) = 3.263e-05, 9.880e-05
# [BatchCDL] Fit in 462.2s
# 	Writing: case_0356_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 7.9  mins.
# Band-pass done, now fitting: case_0356-set2...
# Data shape: (8, 200, 7600) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 7.252e-05, 7.629e-05
# [BatchCDL] Fit in 1050.9s
# 	Writing: case_0356_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 25.5  mins.
# Band-pass done, now fitting: case_0356-set3...
# Data shape: (8, 200, 7875) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.183e-05, 9.400e-05
# [BatchCDL] Fit in 889.3s
# 	Writing: case_0356_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 40.5  mins.
# Band-pass done, now fitting: case_0356-set4...
# Data shape: (8, 200, 8275) ; N of Atoms:  30 ; Sample per atom:  300
# ...............................
# [BatchCDL] Converged after 31 iteration, (dz, du) = 9.742e-05, 9.815e-05
# [BatchCDL] Fit in 1662.6s
# 	Writing: case_0356_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 68.4  mins.
# Band-pass done, now fitting: case_0356-set5...
# Data shape: (8, 200, 7762) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 9.324e-05, 9.610e-05
# [BatchCDL] Fit in 1052.5s
# 	Writing: case_0356_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 86.1  mins.
# Band-pass done, now fitting: case_0400-set1...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 8.298e-05, 9.057e-05
# [BatchCDL] Fit in 606.1s
# 	Writing: case_0400_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.3  mins.
# Band-pass done, now fitting: case_0400-set2...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# .........
# [BatchCDL] Converged after 9 iteration, (dz, du) = 8.691e-05, 9.326e-05
# [BatchCDL] Fit in 484.3s
# 	Writing: case_0400_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 18.5  mins.
# Band-pass done, now fitting: case_0449-set1...
# Data shape: (8, 200, 9900) ; N of Atoms:  30 ; Sample per atom:  300
# ..........
# [BatchCDL] Converged after 10 iteration, (dz, du) = 8.877e-05, 9.057e-05
# [BatchCDL] Fit in 619.0s
# 	Writing: case_0449_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.5  mins.
# Band-pass done, now fitting: case_0449-set2...
# Data shape: (8, 200, 8037) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 9.342e-05, 9.816e-05
# [BatchCDL] Fit in 780.2s
# 	Writing: case_0449_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 23.7  mins.
# Band-pass done, now fitting: case_0299-set2...
# Data shape: (8, 200, 6462) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 5.674e-05, 8.298e-05
# [BatchCDL] Fit in 972.9s
# 	Writing: case_0299_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.3  mins.
# Band-pass done, now fitting: case_0299-set4...
# Data shape: (8, 200, 7650) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 6.407e-05, 8.139e-05
# [BatchCDL] Fit in 704.9s
# 	Writing: case_0299_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 28.2  mins.
# Band-pass done, now fitting: case_0393-set1...
# Data shape: (8, 200, 7850) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 8.403e-05, 8.575e-05
# [BatchCDL] Fit in 638.0s
# 	Writing: case_0393_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.8  mins.
# Band-pass done, now fitting: case_0393-set7...
# Data shape: (8, 200, 7237) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 4.740e-05, 6.534e-05
# [BatchCDL] Fit in 810.2s
# 	Writing: case_0393_1_set07_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 24.4  mins.
# Band-pass done, now fitting: case_0393-set5...
# Data shape: (8, 200, 7900) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 8.238e-05, 8.308e-05
# [BatchCDL] Fit in 775.7s
# 	Writing: case_0393_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 37.5  mins.
# Band-pass done, now fitting: case_0393-set6...
# Data shape: (8, 200, 7150) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 4.348e-05, 9.841e-05
# [BatchCDL] Fit in 765.1s
# 	Writing: case_0393_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 50.4  mins.
# Band-pass done, now fitting: case_0393-set8...
# Data shape: (8, 200, 3750) ; N of Atoms:  30 ; Sample per atom:  300
# ......
# [BatchCDL] Converged after 6 iteration, (dz, du) = 5.349e-05, 7.608e-05
# [BatchCDL] Fit in 458.0s
# 	Writing: case_0393_1_set08_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 58.1  mins.
# Band-pass done, now fitting: case_0393-set2...
# Data shape: (8, 200, 7600) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 7.748e-05, 8.888e-05
# [BatchCDL] Fit in 842.5s
# 	Writing: case_0393_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 72.3  mins.
# Band-pass done, now fitting: case_0393-set3...
# Data shape: (8, 200, 7950) ; N of Atoms:  30 ; Sample per atom:  300
# .......
# [BatchCDL] Converged after 7 iteration, (dz, du) = 5.154e-05, 7.631e-05
# [BatchCDL] Fit in 917.5s
# 	Writing: case_0393_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 87.8  mins.
# Band-pass done, now fitting: case_0393-set4...
# Data shape: (8, 200, 8150) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 8.402e-05, 9.194e-05
# [BatchCDL] Fit in 785.3s
# 	Writing: case_0393_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 101.0  mins.
# Band-pass done, now fitting: case_0291-set1...
# Data shape: (8, 200, 7700) ; N of Atoms:  30 ; Sample per atom:  300
# ....
# [BatchCDL] Converged after 4 iteration, (dz, du) = 8.316e-05, 9.713e-05
# [BatchCDL] Fit in 428.5s
# 	Writing: case_0291_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 7.3  mins.
# Band-pass done, now fitting: case_0291-set2...
# Data shape: (8, 200, 7725) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 6.361e-05, 8.905e-05
# [BatchCDL] Fit in 910.2s
# 	Writing: case_0291_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 22.6  mins.
# Band-pass done, now fitting: case_0220-set1...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 8.614e-05, 9.011e-05
# [BatchCDL] Fit in 761.8s
# 	Writing: case_0220_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.8  mins.
# Band-pass done, now fitting: case_0220-set4...
# Data shape: (8, 200, 8737) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 6.777e-05, 7.576e-05
# [BatchCDL] Fit in 912.0s
# 	Writing: case_0220_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 28.2  mins.
# Band-pass done, now fitting: case_0392-set1...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 8.145e-05, 9.467e-05
# [BatchCDL] Fit in 953.1s
# 	Writing: case_0392_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.0  mins.
# Band-pass done, now fitting: case_0392-set2...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 8.728e-05, 9.374e-05
# [BatchCDL] Fit in 773.0s
# 	Writing: case_0392_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 29.1  mins.
# Band-pass done, now fitting: case_0391-set2...
# Data shape: (8, 200, 7700) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 9.068e-05, 6.867e-05
# [BatchCDL] Fit in 1199.6s
# 	Writing: case_0391_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 20.2  mins.
# Band-pass done, now fitting: case_0391-set3...
# Data shape: (8, 200, 8425) ; N of Atoms:  30 ; Sample per atom:  300
# .....
# [BatchCDL] Converged after 5 iteration, (dz, du) = 4.083e-05, 4.674e-05
# [BatchCDL] Fit in 391.8s
# 	Writing: case_0391_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 26.9  mins.
# Band-pass done, now fitting: case_0199-set2...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 5.968e-05, 8.723e-05
# [BatchCDL] Fit in 819.9s
# 	Writing: case_0199_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.8  mins.
# Band-pass done, now fitting: case_0199-set3...
# Data shape: (8, 200, 8237) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 5.999e-05, 9.390e-05
# [BatchCDL] Fit in 729.5s
# 	Writing: case_0199_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 26.1  mins.
# Band-pass done, now fitting: case_0324-set2...
# Data shape: (8, 200, 9075) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 8.792e-05, 9.787e-05
# [BatchCDL] Fit in 915.0s
# 	Writing: case_0324_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.4  mins.
# Band-pass done, now fitting: case_0324-set3...
# Data shape: (8, 200, 8012) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 9.431e-05, 9.428e-05
# [BatchCDL] Fit in 806.6s
# 	Writing: case_0324_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 29.0  mins.
# Band-pass done, now fitting: case_0347_1-set1...
# Data shape: (8, 200, 6650) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 4.665e-05, 6.210e-05
# [BatchCDL] Fit in 700.7s
# 	Writing: case_0347_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 11.8  mins.
# Band-pass done, now fitting: case_0347_1-set3...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 8.720e-05, 9.631e-05
# [BatchCDL] Fit in 1217.1s
# 	Writing: case_0347_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 32.2  mins.
# Band-pass done, now fitting: case_0228-set1...
# Data shape: (8, 200, 8312) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 8.195e-05, 8.583e-05
# [BatchCDL] Fit in 1040.1s
# 	Writing: case_0228_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.5  mins.
# Band-pass done, now fitting: case_0228-set2...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# .......................
# [BatchCDL] Converged after 23 iteration, (dz, du) = 6.760e-05, 7.880e-05
# [BatchCDL] Fit in 1261.5s
# 	Writing: case_0228_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 38.7  mins.
# Band-pass done, now fitting: case_0195-set2...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.321e-05, 9.981e-05
# [BatchCDL] Fit in 770.2s
# 	Writing: case_0195_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.0  mins.
# Band-pass done, now fitting: case_0195-set4...
# Data shape: (8, 200, 7737) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 5.513e-05, 9.991e-05
# [BatchCDL] Fit in 652.9s
# 	Writing: case_0195_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 24.0  mins.
# Band-pass done, now fitting: case_0212-set1...
# Data shape: (8, 200, 7675) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 6.033e-05, 9.934e-05
# [BatchCDL] Fit in 970.9s
# 	Writing: case_0212_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.3  mins.
# Band-pass done, now fitting: case_0212-set2...
# Data shape: (8, 200, 7537) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 7.767e-05, 9.491e-05
# [BatchCDL] Fit in 956.8s
# 	Writing: case_0212_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 32.4  mins.
# Band-pass done, now fitting: case_0234-set1...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 8.434e-05, 8.501e-05
# [BatchCDL] Fit in 810.6s
# 	Writing: case_0234_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.7  mins.
# Band-pass done, now fitting: case_0234-set2...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.538e-05, 8.987e-05
# [BatchCDL] Fit in 837.1s
# 	Writing: case_0234_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 27.8  mins.
# Band-pass done, now fitting: case_0284-set1...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 9.147e-05, 9.354e-05
# [BatchCDL] Fit in 847.9s
# 	Writing: case_0284_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 14.3  mins.
# Band-pass done, now fitting: case_0284-set2...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 5.470e-05, 8.149e-05
# [BatchCDL] Fit in 914.7s
# 	Writing: case_0284_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 29.7  mins.
# Band-pass done, now fitting: case_0333_2-set2...
# Data shape: (8, 200, 7625) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 9.297e-05, 9.904e-05
# [BatchCDL] Fit in 616.0s
# 	Writing: case_0333_2_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.4  mins.
# Band-pass done, now fitting: case_0333_2-set3...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 8.910e-05, 9.756e-05
# [BatchCDL] Fit in 980.8s
# 	Writing: case_0333_2_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 26.9  mins.
# Band-pass done, now fitting: case_0095-set1...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 8.621e-05, 8.917e-05
# [BatchCDL] Fit in 673.7s
# 	Writing: case_0095_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 11.4  mins.
# Band-pass done, now fitting: case_0095-set2...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 8.974e-05, 9.782e-05
# [BatchCDL] Fit in 686.8s
# 	Writing: case_0095_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 23.0  mins.
# Band-pass done, now fitting: case_0108-set4...
# Data shape: (8, 200, 7487) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 5.794e-05, 8.829e-05
# [BatchCDL] Fit in 723.6s
# 	Writing: case_0108_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.2  mins.
# Band-pass done, now fitting: case_0108-set5...
# Data shape: (8, 200, 10812) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 7.973e-05, 8.514e-05
# [BatchCDL] Fit in 966.6s
# 	Writing: case_0108_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 28.5  mins.
# Band-pass done, now fitting: case_0142-set1...
# Data shape: (8, 200, 7712) ; N of Atoms:  30 ; Sample per atom:  300
# .........
# [BatchCDL] Converged after 9 iteration, (dz, du) = 7.310e-05, 8.305e-05
# [BatchCDL] Fit in 563.9s
# 	Writing: case_0142_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 9.5  mins.
# Band-pass done, now fitting: case_0142-set2...
# Data shape: (8, 200, 7537) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 8.936e-05, 9.462e-05
# [BatchCDL] Fit in 611.2s
# 	Writing: case_0142_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 19.9  mins.
# Band-pass done, now fitting: case_0152-set4...
# Data shape: (8, 200, 7250) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 6.348e-05, 9.745e-05
# [BatchCDL] Fit in 866.7s
# 	Writing: case_0152_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 14.6  mins.
# Band-pass done, now fitting: case_0152-set3...
# Data shape: (8, 200, 7537) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 5.383e-05, 9.733e-05
# [BatchCDL] Fit in 920.1s
# 	Writing: case_0152_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 30.1  mins.
# Band-pass done, now fitting: case_0183_2-set1...
# Data shape: (8, 200, 11275) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 9.643e-05, 9.108e-05
# [BatchCDL] Fit in 645.3s
# 	Writing: case_0183_2_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 11.0  mins.
# Band-pass done, now fitting: case_0183_2-set2...
# Data shape: (8, 200, 15375) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.393e-05, 9.492e-05
# [BatchCDL] Fit in 994.6s
# 	Writing: case_0183_2_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 27.9  mins.
# Band-pass done, now fitting: case_0184-set1...
# Data shape: (8, 200, 8625) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 8.754e-05, 9.131e-05
# [BatchCDL] Fit in 825.9s
# 	Writing: case_0184_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.9  mins.
# Band-pass done, now fitting: case_0184-set2...
# Data shape: (8, 200, 7625) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 8.554e-05, 9.050e-05
# [BatchCDL] Fit in 696.6s
# 	Writing: case_0184_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 25.7  mins.
# Band-pass done, now fitting: case_0184-set3...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.688e-05, 9.097e-05
# [BatchCDL] Fit in 882.1s
# 	Writing: case_0184_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 40.5  mins.
# Band-pass done, now fitting: case_0184-set4...
# Data shape: (8, 200, 8075) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 9.648e-05, 9.018e-05
# [BatchCDL] Fit in 1224.0s
# 	Writing: case_0184_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 61.1  mins.
# Band-pass done, now fitting: case_0217-set3...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 7.777e-05, 8.571e-05
# [BatchCDL] Fit in 888.2s
# 	Writing: case_0217_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 14.9  mins.
# Band-pass done, now fitting: case_0217-set5...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 9.444e-05, 9.204e-05
# [BatchCDL] Fit in 900.3s
# 	Writing: case_0217_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 30.1  mins.
# Band-pass done, now fitting: case_0266-set3...
# Data shape: (8, 200, 7562) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 9.196e-05, 9.973e-05
# [BatchCDL] Fit in 888.9s
# 	Writing: case_0266_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.0  mins.
# Band-pass done, now fitting: case_0266-set4...
# Data shape: (8, 200, 7562) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.568e-05, 8.834e-05
# [BatchCDL] Fit in 863.2s
# 	Writing: case_0266_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 29.5  mins.
# Band-pass done, now fitting: case_0255-set1...
# Data shape: (8, 200, 5312) ; N of Atoms:  30 ; Sample per atom:  300
# ......................
# [BatchCDL] Converged after 22 iteration, (dz, du) = 8.068e-05, 7.580e-05
# [BatchCDL] Fit in 1050.5s
# 	Writing: case_0255_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.6  mins.
# Band-pass done, now fitting: case_0255-set3...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.931e-05, 9.511e-05
# [BatchCDL] Fit in 818.3s
# 	Writing: case_0255_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 31.4  mins.
# Band-pass done, now fitting: case_0268-set2...
# Data shape: (8, 200, 3862) ; N of Atoms:  30 ; Sample per atom:  300
# ......................
# [BatchCDL] Converged after 22 iteration, (dz, du) = 6.182e-05, 9.363e-05
# [BatchCDL] Fit in 988.4s
# 	Writing: case_0268_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.5  mins.
# Band-pass done, now fitting: case_0268-set3...
# Data shape: (8, 200, 7562) ; N of Atoms:  30 ; Sample per atom:  300
# ...................
# [BatchCDL] Converged after 19 iteration, (dz, du) = 9.219e-05, 9.758e-05
# [BatchCDL] Fit in 1173.7s
# 	Writing: case_0268_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 36.3  mins.
# Band-pass done, now fitting: case_0287-set2...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ...................
# [BatchCDL] Converged after 19 iteration, (dz, du) = 8.522e-05, 9.984e-05
# [BatchCDL] Fit in 1002.5s
# 	Writing: case_0287_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.9  mins.
# Band-pass done, now fitting: case_0287-set3...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 8.433e-05, 9.061e-05
# [BatchCDL] Fit in 1128.2s
# 	Writing: case_0287_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 35.8  mins.
# Band-pass done, now fitting: case_0257-set7...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# .......
# [BatchCDL] Converged after 7 iteration, (dz, du) = 7.239e-05, 8.727e-05
# [BatchCDL] Fit in 393.9s
# 	Writing: case_0257_1_set07_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 6.7  mins.
# Band-pass done, now fitting: case_0257-set3...
# Data shape: (8, 200, 7700) ; N of Atoms:  30 ; Sample per atom:  300
# ....
# [BatchCDL] Converged after 4 iteration, (dz, du) = 7.057e-05, 6.172e-05
# [BatchCDL] Fit in 255.3s
# 	Writing: case_0257_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 11.1  mins.
# Band-pass done, now fitting: case_0438_1-set3...
# Data shape: (8, 200, 8575) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 7.312e-05, 8.938e-05
# [BatchCDL] Fit in 966.1s
# 	Writing: case_0438_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.3  mins.
# Band-pass done, now fitting: case_0438_1-set2...
# Data shape: (8, 200, 6175) ; N of Atoms:  30 ; Sample per atom:  300
# .......................
# [BatchCDL] Converged after 23 iteration, (dz, du) = 6.323e-05, 8.383e-05
# [BatchCDL] Fit in 1206.4s
# 	Writing: case_0438_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 36.5  mins.
# Band-pass done, now fitting: case_0438_1-set4...
# Data shape: (8, 200, 5462) ; N of Atoms:  30 ; Sample per atom:  300
# ........................
# [BatchCDL] Converged after 24 iteration, (dz, du) = 6.318e-05, 9.352e-05
# [BatchCDL] Fit in 1248.9s
# 	Writing: case_0438_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 57.4  mins.
# Band-pass done, now fitting: case_0438_1-set5...
# Data shape: (8, 200, 8062) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 8.116e-05, 9.869e-05
# [BatchCDL] Fit in 1152.0s
# 	Writing: case_0438_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 76.8  mins.
# Band-pass done, now fitting: case_0438_1-set6...
# Data shape: (8, 200, 4912) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 7.055e-05, 9.287e-05
# [BatchCDL] Fit in 808.7s
# 	Writing: case_0438_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 90.3  mins.
# Band-pass done, now fitting: case_0203_1-set4...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# ..........................
# [BatchCDL] Converged after 26 iteration, (dz, du) = 8.445e-05, 8.288e-05
# [BatchCDL] Fit in 1393.1s
# 	Writing: case_0203_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 23.4  mins.
# Band-pass done, now fitting: case_0203_1-set3...
# Data shape: (8, 200, 7675) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 7.548e-05, 9.537e-05
# [BatchCDL] Fit in 846.0s
# 	Writing: case_0203_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 37.6  mins.
# Band-pass done, now fitting: case_0260-set1...
# Data shape: (8, 200, 6325) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 7.538e-05, 7.480e-05
# [BatchCDL] Fit in 1045.8s
# 	Writing: case_0260_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.6  mins.
# Band-pass done, now fitting: case_0260-set2...
# Data shape: (8, 200, 7787) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 6.286e-05, 9.063e-05
# [BatchCDL] Fit in 1025.7s
# 	Writing: case_0260_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 34.8  mins.
# Band-pass done, now fitting: case_0293-set2...
# Data shape: (8, 200, 7862) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 8.614e-05, 8.946e-05
# [BatchCDL] Fit in 756.2s
# 	Writing: case_0293_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.8  mins.
# Band-pass done, now fitting: case_0293-set3...
# Data shape: (8, 200, 7712) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 8.931e-05, 9.748e-05
# [BatchCDL] Fit in 745.1s
# 	Writing: case_0293_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 25.3  mins.
# Band-pass done, now fitting: case_0295_1-set2...
# Data shape: (8, 200, 1275) ; N of Atoms:  30 ; Sample per atom:  300
# .........
# [BatchCDL] Converged after 9 iteration, (dz, du) = 1.456e-05, 9.338e-05
# [BatchCDL] Fit in 1066.5s
# 	Writing: case_0295_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.8  mins.
# Band-pass done, now fitting: case_0147-set1...
# Data shape: (8, 200, 27487) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.205e-05, 7.879e-05
# [BatchCDL] Fit in 1458.2s
# 	Writing: case_0147_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 24.8  mins.
# Band-pass done, now fitting: case_0176-set2...
# Data shape: (8, 200, 7687) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 8.440e-05, 8.637e-05
# [BatchCDL] Fit in 1130.4s
# 	Writing: case_0176_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 19.0  mins.
# Band-pass done, now fitting: case_0176-set4...
# Data shape: (8, 200, 7662) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 8.426e-05, 9.923e-05
# [BatchCDL] Fit in 942.0s
# 	Writing: case_0176_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 34.8  mins.
# Band-pass done, now fitting: case_0187-set1...
# Data shape: (8, 200, 7850) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 8.405e-05, 8.305e-05
# [BatchCDL] Fit in 1013.9s
# 	Writing: case_0187_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.1  mins.
# Band-pass done, now fitting: case_0187-set2...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 8.728e-05, 9.296e-05
# [BatchCDL] Fit in 611.6s
# 	Writing: case_0187_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 27.4  mins.
# Band-pass done, now fitting: case_0197-set1...
# Data shape: (8, 200, 6112) ; N of Atoms:  30 ; Sample per atom:  300
# ..........................
# [BatchCDL] Converged after 26 iteration, (dz, du) = 7.715e-05, 9.119e-05
# [BatchCDL] Fit in 1412.5s
# 	Writing: case_0197_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 23.7  mins.
# Band-pass done, now fitting: case_0197-set2...
# Data shape: (8, 200, 8687) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 5.851e-05, 7.169e-05
# [BatchCDL] Fit in 996.6s
# 	Writing: case_0197_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 40.4  mins.
# Band-pass done, now fitting: case_0213-set1...
# Data shape: (8, 200, 9350) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 7.506e-05, 9.894e-05
# [BatchCDL] Fit in 1049.1s
# 	Writing: case_0213_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.7  mins.
# Band-pass done, now fitting: case_0213-set2...
# Data shape: (8, 200, 7312) ; N of Atoms:  30 ; Sample per atom:  300
# ......................
# [BatchCDL] Converged after 22 iteration, (dz, du) = 8.897e-05, 9.364e-05
# [BatchCDL] Fit in 1191.4s
# 	Writing: case_0213_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 37.7  mins.
# Band-pass done, now fitting: case_0214-set2...
# Data shape: (8, 200, 6312) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 6.570e-05, 7.662e-05
# [BatchCDL] Fit in 1066.4s
# 	Writing: case_0214_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.9  mins.
# Band-pass done, now fitting: case_0214-set5...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 7.705e-05, 9.193e-05
# [BatchCDL] Fit in 715.2s
# 	Writing: case_0214_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 30.0  mins.
# Band-pass done, now fitting: case_0420-set3...
# Data shape: (8, 200, 7725) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.546e-05, 8.846e-05
# [BatchCDL] Fit in 780.3s
# 	Writing: case_0420_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.2  mins.
# Band-pass done, now fitting: case_0420-set4...
# Data shape: (8, 200, 7687) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# ...
# Band-pass done, now fitting: case_0323-set6...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 7.511e-05, 9.642e-05
# [BatchCDL] Fit in 875.8s
# 	Writing: case_0323_1_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 59.7  mins.
# Band-pass done, now fitting: case_0330-set1...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# ...........
# [BatchCDL] Converged after 11 iteration, (dz, du) = 8.504e-05, 9.844e-05
# [BatchCDL] Fit in 622.9s
# 	Writing: case_0330_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.5  mins.
# Band-pass done, now fitting: case_0330-set2...
# Data shape: (8, 200, 7575) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 6.203e-05, 8.173e-05
# [BatchCDL] Fit in 894.1s
# 	Writing: case_0330_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 25.6  mins.
# Band-pass done, now fitting: case_0334-set1...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 8.780e-05, 9.479e-05
# [BatchCDL] Fit in 860.2s
# 	Writing: case_0334_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 14.5  mins.
# Band-pass done, now fitting: case_0334-set2...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# .........
# [BatchCDL] Converged after 9 iteration, (dz, du) = 6.161e-05, 9.148e-05
# [BatchCDL] Fit in 647.1s
# 	Writing: case_0334_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 25.4  mins.
# Band-pass done, now fitting: case_0339-set1...
# Data shape: (8, 200, 7675) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.421e-05, 9.002e-05
# [BatchCDL] Fit in 780.8s
# 	Writing: case_0339_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.2  mins.
# Band-pass done, now fitting: case_0339-set2...
# Data shape: (8, 200, 8112) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 4.920e-05, 9.998e-05
# [BatchCDL] Fit in 738.9s
# 	Writing: case_0339_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 25.7  mins.
# Band-pass done, now fitting: case_0351-set1...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# ...................
# [BatchCDL] Converged after 19 iteration, (dz, du) = 6.003e-05, 9.255e-05
# [BatchCDL] Fit in 1071.0s
# 	Writing: case_0351_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 18.0  mins.
# Band-pass done, now fitting: case_0351-set2...
# Data shape: (8, 200, 8700) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 9.335e-05, 9.314e-05
# [BatchCDL] Fit in 864.3s
# 	Writing: case_0351_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 32.6  mins.
# Band-pass done, now fitting: case_0352-set1...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 8.411e-05, 8.857e-05
# [BatchCDL] Fit in 778.9s
# 	Writing: case_0352_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.1  mins.
# Band-pass done, now fitting: case_0352-set2...
# Data shape: (8, 200, 8012) ; N of Atoms:  30 ; Sample per atom:  300
# ............
# [BatchCDL] Converged after 12 iteration, (dz, du) = 6.910e-05, 9.761e-05
# [BatchCDL] Fit in 679.5s
# 	Writing: case_0352_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 24.6  mins.
# Band-pass done, now fitting: case_0140-set9...
# Data shape: (8, 200, 3962) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 7.166e-05, 9.156e-05
# [BatchCDL] Fit in 638.8s
# 	Writing: case_0140_1_set09_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.7  mins.
# Band-pass done, now fitting: case_0452-set1...
# Data shape: (8, 200, 8287) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 9.949e-05, 8.442e-05
# [BatchCDL] Fit in 922.1s
# 	Writing: case_0452_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.5  mins.
# Band-pass done, now fitting: case_0452-set2...
# Data shape: (8, 200, 7825) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 9.705e-05, 9.364e-05
# [BatchCDL] Fit in 1172.8s
# 	Writing: case_0452_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 35.3  mins.
# Band-pass done, now fitting: case_0452-set3...
# Data shape: (8, 200, 7837) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 9.228e-05, 8.879e-05
# [BatchCDL] Fit in 1200.6s
# 	Writing: case_0452_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 55.4  mins.
# Band-pass done, now fitting: case_0390_0-set3...
# Data shape: (8, 200, 7537) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 9.514e-05, 9.923e-05
# [BatchCDL] Fit in 766.8s
# 	Writing: case_0390_0_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.9  mins.
# Band-pass done, now fitting: case_0390_0-set2...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ......................
# [BatchCDL] Converged after 22 iteration, (dz, du) = 6.665e-05, 6.256e-05
# [BatchCDL] Fit in 1264.7s
# 	Writing: case_0390_0_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 34.2  mins.
# Band-pass done, now fitting: case_0390_0-set4...
# Data shape: (8, 200, 7662) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 9.475e-05, 9.808e-05
# [BatchCDL] Fit in 1028.7s
# 	Writing: case_0390_0_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 51.5  mins.
#
# N of atoms:  30 , Num of Jobs:  80
# Low:  30 Hz, High: 1 Hz
# Finished at: 2024-12-19 16:50:06
# Total time spent: 4646.0  mins.
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.546e-05, 8.846e-05
# [BatchCDL] Fit in 814.6s
# 	Writing: case_0420_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.7  mins.
# Band-pass done, now fitting: case_0390_0-set3...
# Data shape: (8, 200, 7537) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 9.514e-05, 9.923e-05
# [BatchCDL] Fit in 799.7s
# 	Writing: case_0390_0_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.5  mins.
# Band-pass done, now fitting: case_0390_0-set2...
# Data shape: (8, 200, 7512) ; N of Atoms:  30 ; Sample per atom:  300
# ......................
# [BatchCDL] Converged after 22 iteration, (dz, du) = 6.665e-05, 6.256e-05
# [BatchCDL] Fit in 1339.3s
# 	Writing: case_0390_0_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 35.9  mins.
# Band-pass done, now fitting: case_0390_0-set4...
# Data shape: (8, 200, 7662) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 9.475e-05, 9.808e-05
# [BatchCDL] Fit in 1084.0s
# 	Writing: case_0390_0_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 54.2  mins.
# Band-pass done, now fitting: case_0444_0-set2...
# Data shape: (8, 200, 8125) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 1.810e-05, 4.772e-05
# [BatchCDL] Fit in 1018.5s
# 	Writing: case_0444_0_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.1  mins.
# Band-pass done, now fitting: case_0444_0-set3...
# Data shape: (8, 200, 8362) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 8.912e-05, 8.542e-05
# [BatchCDL] Fit in 1244.5s
# 	Writing: case_0444_0_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 38.0  mins.
# Band-pass done, now fitting: case_0444_0-set4...
# Data shape: (8, 200, 8012) ; N of Atoms:  30 ; Sample per atom:  300
# .......................
# [BatchCDL] Converged after 23 iteration, (dz, du) = 8.345e-05, 9.366e-05
# [BatchCDL] Fit in 1299.8s
# 	Writing: case_0444_0_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 59.8  mins.
# Band-pass done, now fitting: case_0444_0-set1...
# Data shape: (8, 200, 8037) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 7.204e-05, 9.746e-05
# [BatchCDL] Fit in 1247.4s
# 	Writing: case_0444_0_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 80.8  mins.
# Band-pass done, now fitting: case_0444_0-set5...
# Data shape: (8, 200, 5675) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 8.343e-05, 9.605e-05
# [BatchCDL] Fit in 948.4s
# 	Writing: case_0444_0_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 96.7  mins.
# Band-pass done, now fitting: case_0434_0-set2...
# Data shape: (8, 200, 7800) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 8.451e-05, 8.730e-05
# [BatchCDL] Fit in 1068.3s
# 	Writing: case_0434_0_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 18.0  mins.
# Band-pass done, now fitting: case_0434_0-set3...
# Data shape: (8, 200, 9487) ; N of Atoms:  30 ; Sample per atom:  300
# ...................
# [BatchCDL] Converged after 19 iteration, (dz, du) = 8.991e-05, 9.576e-05
# [BatchCDL] Fit in 1240.2s
# 	Writing: case_0434_0_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 38.8  mins.
# Band-pass done, now fitting: case_0434_0-set4...
# Data shape: (8, 200, 7887) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 9.217e-05, 9.892e-05
# [BatchCDL] Fit in 880.2s
# 	Writing: case_0434_0_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 53.6  mins.
# Band-pass done, now fitting: case_0434_0-set5...
# Data shape: (8, 200, 7800) ; N of Atoms:  30 ; Sample per atom:  300
# ...............
# [BatchCDL] Converged after 15 iteration, (dz, du) = 9.691e-05, 9.725e-05
# [BatchCDL] Fit in 883.9s
# 	Writing: case_0434_0_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 68.5  mins.
# Band-pass done, now fitting: case_0434_0-set6...
# Data shape: (8, 200, 7750) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 8.105e-05, 7.993e-05
# [BatchCDL] Fit in 1013.5s
# 	Writing: case_0434_0_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 85.5  mins.
# Band-pass done, now fitting: case_0434_0-set7...
# Data shape: (8, 200, 3975) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 9.174e-05, 9.538e-05
# [BatchCDL] Fit in 769.7s
# 	Writing: case_0434_0_set07_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 98.4  mins.
# Band-pass done, now fitting: case_0310-set3...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 9.085e-05, 9.897e-05
# [BatchCDL] Fit in 761.4s
# 	Writing: case_0310_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.8  mins.
# Band-pass done, now fitting: case_0138_2-set3...
# Data shape: (8, 200, 7525) ; N of Atoms:  30 ; Sample per atom:  300
# ........
# [BatchCDL] Converged after 8 iteration, (dz, du) = 8.129e-05, 8.769e-05
# [BatchCDL] Fit in 452.8s
# 	Writing: case_0138_2_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 7.7  mins.
# Band-pass done, now fitting: case_0138_2-set6...
# Data shape: (8, 200, 7250) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 4.983e-05, 8.796e-05
# [BatchCDL] Fit in 796.8s
# 	Writing: case_0138_2_set06_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 21.1  mins.
# Band-pass done, now fitting: case_0017-set2...
# Data shape: (8, 200, 16525) ; N of Atoms:  30 ; Sample per atom:  300
# .............
# [BatchCDL] Converged after 13 iteration, (dz, du) = 9.042e-05, 9.313e-05
# [BatchCDL] Fit in 970.1s
# 	Writing: case_0017_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 16.5  mins.
# Band-pass done, now fitting: case_0106-set3...
# Data shape: (8, 200, 7587) ; N of Atoms:  30 ; Sample per atom:  300
# ................
# [BatchCDL] Converged after 16 iteration, (dz, du) = 7.413e-05, 8.669e-05
# [BatchCDL] Fit in 920.8s
# 	Writing: case_0106_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.5  mins.
# Band-pass done, now fitting: case_0116-set1...
# Data shape: (8, 200, 1625) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 5.192e-05, 7.508e-05
# [BatchCDL] Fit in 718.0s
# 	Writing: case_0116_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 12.0  mins.
# Band-pass done, now fitting: case_0118-set3...
# Data shape: (8, 200, 7550) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 5.974e-05, 8.889e-05
# [BatchCDL] Fit in 1034.9s
# 	Writing: case_0118_1_set03_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.4  mins.
# Band-pass done, now fitting: case_0240_1-set5...
# Data shape: (8, 200, 7887) ; N of Atoms:  30 ; Sample per atom:  300
# .....................
# [BatchCDL] Converged after 21 iteration, (dz, du) = 5.077e-05, 6.742e-05
# [BatchCDL] Fit in 1256.7s
# 	Writing: case_0240_1_set05_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 21.1  mins.
# Band-pass done, now fitting: case_0253_1-set4...
# Data shape: (8, 200, 10862) ; N of Atoms:  30 ; Sample per atom:  300
# ..................
# [BatchCDL] Converged after 18 iteration, (dz, du) = 8.124e-05, 8.905e-05
# [BatchCDL] Fit in 1152.8s
# 	Writing: case_0253_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 19.4  mins.
# Band-pass done, now fitting: case_0080-set1...
# Data shape: (8, 200, 14487) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.890e-05, 9.046e-05
# [BatchCDL] Fit in 1039.9s
# 	Writing: case_0080_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 17.6  mins.
# Band-pass done, now fitting: case_0037-set4...
# Data shape: (8, 200, 15300) ; N of Atoms:  30 ; Sample per atom:  300
# ..........
# [BatchCDL] Converged after 10 iteration, (dz, du) = 9.678e-05, 9.980e-05
# [BatchCDL] Fit in 799.6s
# 	Writing: case_0037_1_set04_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 13.6  mins.
# Band-pass done, now fitting: case_0059-set1...
# Data shape: (8, 200, 15162) ; N of Atoms:  30 ; Sample per atom:  300
# ........
# [BatchCDL] Converged after 8 iteration, (dz, du) = 9.626e-05, 9.395e-05
# [BatchCDL] Fit in 606.6s
# 	Writing: case_0059_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 10.4  mins.
# Band-pass done, now fitting: case_0065-set2...
# Data shape: (8, 200, 6087) ; N of Atoms:  30 ; Sample per atom:  300
# ....................
# [BatchCDL] Converged after 20 iteration, (dz, du) = 5.430e-05, 9.915e-05
# [BatchCDL] Fit in 1108.3s
# 	Writing: case_0065_1_set02_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 18.6  mins.
# Band-pass done, now fitting: case_0074-set1...
# Data shape: (8, 200, 11300) ; N of Atoms:  30 ; Sample per atom:  300
# ..............
# [BatchCDL] Converged after 14 iteration, (dz, du) = 7.210e-05, 8.204e-05
# [BatchCDL] Fit in 901.4s
# 	Writing: case_0074_1_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 15.2  mins.
# Band-pass done, now fitting: case_0068_2-set1...
# Data shape: (8, 200, 15837) ; N of Atoms:  30 ; Sample per atom:  300
# .................
# [BatchCDL] Converged after 17 iteration, (dz, du) = 9.438e-05, 9.529e-05
# [BatchCDL] Fit in 1232.0s
# 	Writing: case_0068_2_set01_BB_1-30Hz_30_Atoms_3(s)_NormParcTS(True).mat
# 	Time spent: 20.8  mins.
#
# N of atoms:  30 , Num of Jobs:  80
# Low:  30 Hz, High: 1 Hz
# Finished at: 2024-11-30 12:16:35
# Total time spent: 1312.6  mins.
