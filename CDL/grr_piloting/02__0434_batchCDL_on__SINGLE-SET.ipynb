# %%
from scipy.io import loadmat
from scipy.io import savemat 
import numpy as np
import matplotlib.pyplot as plt
from alphacsc import GreedyCDL
from alphacsc.utils import split_signal
from scipy import signal
from scipy.signal import butter, filtfilt
from matplotlib import gridspec
import time
from alphacsc import BatchCDL

# %%
def butter_lowpass(data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low')
    y = filtfilt(b, a, data)
    return y

def butter_highpass(data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='high')
    y = filtfilt(b, a, data)
    return y

# %%
#################################################################
## all parameters are set here
#################################################################
ori_fs             = 1000 # Original sampling rate (Hz)
decimate           = 10   # dec factor for analysis data
HI_PASS            = 2    #Hz 
LOW_PASS           = 30   #Hz
fs                 = ori_fs // decimate  # decimated signal fs
n_atoms            = 12
ATOM_DURATION      = 2    # seconds
N_JOBS             = 80   # cdl jobs

# %%
#filepath = '/data/sheng/MEG_source_data/case_0434/set2/parcel_ts/set2_parc2018yeo17_200_1000_weighted.npy'
#filepath = '/data/sheng/MEG_source_data/case_0434/set3/parcel_ts/set3_parc2018yeo17_200_1000_weighted.npy'
#filepath = '/data/sheng/MEG_source_data/case_0434/set4/parcel_ts/set4_parc2018yeo17_200_1000_weighted.npy'
#filepath = '/data/sheng/MEG_source_data/case_0434/set5/parcel_ts/set5_parc2018yeo17_200_1000_weighted.npy'
#filepath = '/data/sheng/MEG_source_data/case_0434/set6/parcel_ts/set6_parc2018yeo17_200_1000_weighted.npy'
filepath = '/data/sheng/MEG_source_data/case_0434/set7/parcel_ts/set7_parc2018yeo17_200_1000_weighted.npy'

parcelTS           = np.load(filepath) # data: channels x samples
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[123], line 18
#       1 #filepath = '/data/sheng/MEG_source_data/case_0444/set1/parcel_ts/set1_parc2018yeo17_200_1000_weighted.npy'
#       2 #filepath = '/data/sheng/MEG_source_data/case_0444/set2/parcel_ts/set2_parc2018yeo17_200_1000_weighted.npy'
#       3 #filepath = '/data/sheng/MEG_source_data/case_0444/set3/parcel_ts/set3_parc2018yeo17_200_1000_weighted.npy'
#    (...)
#      14
#      15 # 2-6
#      16 filepath = '/data/sheng/MEG_source_data/case_0438_1/set2/parcel_ts/set7_parc2018yeo17_200_1000_weighted.npy'
# ---> 18 parcelTS           = np.load(filepath) # data: channels x samples
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/sheng/MEG_source_data/case_0438_1/set2/parcel_ts/set7_parc2018yeo17_200_1000_weighted.npy'

# %%
# visualize the traces

VISUALIZE_TRACES = False

if VISUALIZE_TRACES:     
    BLOCK_SIZE = 5 # Seconds
    BLOCK_N    = 15
    plt.figure(figsize=(20, 25))
    for i in range(BLOCK_N):
        plt.subplot(BLOCK_N, 1, i+1)

        # gray: orig TS
        plt.plot(np.linspace(0, BLOCK_SIZE, ori_fs*BLOCK_SIZE), 
                 aParcelTS[i*ori_fs*BLOCK_SIZE:(i+1)*ori_fs*BLOCK_SIZE], 'k', alpha=0.33)

        # black: filtered data
        plt.plot(np.linspace(0, BLOCK_SIZE, ori_fs*BLOCK_SIZE), 
                 highpass[i*ori_fs*BLOCK_SIZE:(i+1)*ori_fs*BLOCK_SIZE], 'k')

        # red: filtered and decimated
        plt.plot(np.linspace(0, BLOCK_SIZE, fs*BLOCK_SIZE), data[i*fs*BLOCK_SIZE:(i+1)*fs*BLOCK_SIZE], 'r')

# %%
PARC_N       = parcelTS.shape[0]
SAMPLE_N     = signal.decimate(parcelTS[0], decimate).shape[0]
bpTS         = np.zeros([PARC_N, SAMPLE_N])


# band-pass the data, and decimate if need be #######################
for i in np.arange(0,200):
    
    aParcelTS            = parcelTS[i]    
    lowpass_data         = butter_lowpass(aParcelTS, LOW_PASS, ori_fs)
    highpass             = butter_highpass(lowpass_data, HI_PASS, ori_fs)
    bpTS[i, :]           = signal.decimate(highpass, decimate)
    
del lowpass_data
print('Band-pass done for the parcel time series, now you can fit it with BatchCDL!')
# Out:
# Band-pass done for the parcel time series, now you can fit it with BatchCDL!

# %%
split_parcTS = split_signal(bpTS[None], 8)

# Define the shape of the dictionary
n_times_atom = int(round(fs * ATOM_DURATION)) 
print('Data shape:', split_parcTS.shape, '; n_times_atom: ', n_times_atom)


cdl = BatchCDL(
    # Shape of the dictionary
    n_atoms=n_atoms,
    n_times_atom=n_times_atom,
    # Request a rank1 dictionary with unit norm temporal and spatial maps
    rank1=True, uv_constraint='separate',
    # Initialize the dictionary with random chunk from the data
    D_init='chunk',
    # rescale the regularization parameter to be 20% of lambda_max
    lmbd_max="scaled", reg=.2,
    # Number of iteration for the alternate minimization and cvg threshold
    n_iter=100, eps=1e-4,
    # solver for the z-step
    solver_z="lgcd", solver_z_kwargs={'tol': 1e-2, 'max_iter': 1000},
    # solver for the d-step
    solver_d='alternate_adaptive', solver_d_kwargs={'max_iter': 300},
    # Technical parameters
    verbose=10, random_state=0, n_jobs=N_JOBS)



######################################### FIT ITsplit_parcTS = split_signal(bpTS[None], 8)

# Define the shape of the dictionary
n_times_atom = int(round(fs * ATOM_DURATION)) 
print('Data shape:', split_parcTS.shape, '; n_times_atom: ', n_times_atom)


cdl = BatchCDL(
    # Shape of the dictionary
    n_atoms=n_atoms,
    n_times_atom=n_times_atom,
    # Request a rank1 dictionary with unit norm temporal and spatial maps
    rank1=True, uv_constraint='separate',
    # Initialize the dictionary with random chunk from the data
    D_init='chunk',
    # rescale the regularization parameter to be 20% of lambda_max
    lmbd_max="scaled", reg=.2,
    # Number of iteration for the alternate minimization and cvg threshold
    n_iter=100, eps=1e-4,
    # solver for the z-step
    solver_z="lgcd", solver_z_kwargs={'tol': 1e-2, 'max_iter': 1000},
    # solver for the d-step
    solver_d='alternate_adaptive', solver_d_kwargs={'max_iter': 300},
    # Technical parameters
    verbose=10, random_state=0, n_jobs=N_JOBS)



######################################### FIT IT
print('Start fitting now ...')
t1 = time.time()
cdl.fit(split_parcTS)
del split_parcTS   
######################################### FIT IT

t2 = time.time()

print('\nN of atoms: ', n_atoms, ', Num of Jobs: ', N_JOBS)
print('Low: ', LOW_PASS, 'Hz, High:', HI_PASS, 'Hz')
print(f"Finished at: {time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(t2))}")
print('Time spent:', (t2-t1)/60, ' mins.' )
# Out:
# Data shape: (8, 200, 3975) ; n_times_atom:  200
# Data shape: (8, 200, 3975) ; n_times_atom:  200
# Start fitting now ...
# [BatchCDL] CD iterations 0 / 100
# [BatchCDL] lambda = 3.086e+01
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[126], line 60
#      58 print('Start fitting now ...')
#      59 t1 = time.time()
# ---> 60 cdl.fit(split_parcTS)
#      61 del split_parcTS
#      62 ######################################### FIT IT
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/alphacsc/convolutional_dictionary_learning.py:189, in ConvolutionalDictionaryLearning.fit(self, X, y)
#     186 def fit(self, X, y=None):
#     187     """Learn a convolutional dictionary from the set of signals X.
#     188     """
# --> 189     res = learn_d_z_multi(
#     190         X, self.n_atoms, self.n_times_atom,
#     191         reg=self.reg, lmbd_max=self.lmbd_max,
#     192         rank1=self.rank1, window=self.window,
#     193         uv_constraint=self.uv_constraint,
#     194         algorithm=self.algorithm, algorithm_params=self.algorithm_params,
#     195         n_iter=self.n_iter, eps=self.eps,
#     196         solver_z=self.solver_z, solver_z_kwargs=self.solver_z_kwargs,
#     197         solver_d=self.solver_d, solver_d_kwargs=self.solver_d_kwargs,
#     198         D_init=self.D_init,
#     199         unbiased_z_hat=False, verbose=self.verbose, callback=self.callback,
#     200         random_state=self.random_state, n_jobs=self.n_jobs,
#     201         name=self.name, raise_on_increase=self.raise_on_increase,
#     202         sort_atoms=self.sort_atoms
#     203     )
#     205     self._pobj, self._times, self._D_hat, self._z_hat, self.reg_ = res
#     206     self.n_channels_ = X.shape[1]
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/alphacsc/learn_d_z_multi.py:200, in learn_d_z_multi(X, n_atoms, n_times_atom, n_iter, n_jobs, lmbd_max, reg, rank1, uv_constraint, eps, algorithm, algorithm_params, solver_z, solver_z_kwargs, solver_d, solver_d_kwargs, D_init, unbiased_z_hat, stopping_pobj, raise_on_increase, verbose, callback, random_state, name, window, sort_atoms)
#     197 kwargs.update(algorithm_params)
#     199 if algorithm == 'batch':
# --> 200     pobj, times = _batch_learn(greedy=False, **kwargs)
#     201 elif algorithm == "greedy":
#     202     pobj, times = _batch_learn(greedy=True, **kwargs)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/alphacsc/learn_d_z_multi.py:288, in _batch_learn(z_encoder, d_solver, end_iter_func, n_iter, lmbd_max, reg, verbose, greedy, random_state, name)
#     286 # Compute z update
#     287 start = time.time()
# --> 288 z_encoder.compute_z()
#     290 # monitor cost function
#     291 times.append(time.time() - start)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/alphacsc/_z_encoder.py:278, in AlphaCSCEncoder.compute_z(self, unbiased_z_hat)
#     277 def compute_z(self, unbiased_z_hat=False):
# --> 278     self.z_hat, self.ztz, self.ztX = self._compute_z_aux(self.X,
#     279                                                          self.z_hat,
#     280                                                          unbiased_z_hat)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/alphacsc/_z_encoder.py:271, in AlphaCSCEncoder._compute_z_aux(self, X, z0, unbiased_z_hat)
#     268 def _compute_z_aux(self, X, z0, unbiased_z_hat):
#     269     reg = self.reg if not unbiased_z_hat else 0
# --> 271     return update_z_multi(
#     272         X, self.D_hat, reg=reg, z0=z0, solver=self.solver,
#     273         solver_kwargs=self.solver_kwargs, freeze_support=unbiased_z_hat,
#     274         n_jobs=self.n_jobs, return_ztz=True
#     275     )
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/alphacsc/update_z_multi.py:78, in update_z_multi(X, D, reg, z0, solver, solver_kwargs, freeze_support, return_ztz, timing, n_jobs, random_state, debug)
#      75 # now estimate the codes
#      76 delayed_update_z = delayed(_update_z_multi_idx)
# ---> 78 results = Parallel(n_jobs=n_jobs)(
#      79     delayed_update_z(X[i], D, reg, z0[i], debug, solver, solver_kwargs,
#      80                      freeze_support, return_ztz=return_ztz,
#      81                      timing=timing, random_state=seed)
#      82     for i, seed in enumerate(parallel_seeds))
#      84 # Post process the results to get separate objects
#      85 z_hats, pobj, times = [], [], []
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/parallel.py:2005, in Parallel.__call__(self, iterable)
#    1999 self._call_ref = weakref.ref(output)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
# -> 2005 next(output)
#    2007 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/parallel.py:1643, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1641 detach_generator_exit = False
#    1642 try:
# -> 1643     self._start(iterator, pre_dispatch)
#    1644     # first yield returns None, for internal use only. This ensures
#    1645     # that we enter the try/except block and start dispatching the
#    1646     # tasks.
#    1647     yield
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/parallel.py:1626, in Parallel._start(self, iterator, pre_dispatch)
#    1617 def _start(self, iterator, pre_dispatch):
#    1618     # Only set self._iterating to True if at least a batch
#    1619     # was dispatched. In particular this covers the edge
#    (...)
#    1623     # was very quick and its callback already dispatched all the
#    1624     # remaining jobs.
#    1625     self._iterating = False
# -> 1626     if self.dispatch_one_batch(iterator):
#    1627         self._iterating = self._original_iterator is not None
#    1629     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/parallel.py:1517, in Parallel.dispatch_one_batch(self, iterator)
#    1515     return False
#    1516 else:
# -> 1517     self._dispatch(tasks)
#    1518     return True
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/parallel.py:1418, in Parallel._dispatch(self, batch)
#    1411     self._jobs.append(batch_tracker)
#    1413 # If return_ordered is False, the batch_tracker is not stored in the
#    1414 # jobs queue at the time of submission. Instead, it will be appended to
#    1415 # the queue by itself as soon as the callback is triggered to be able
#    1416 # to return the results in the order of completion.
# -> 1418 job = self._backend.apply_async(batch, callback=batch_tracker)
#    1419 batch_tracker.register_job(job)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/_parallel_backends.py:588, in LokyBackend.apply_async(self, func, callback)
#     586 def apply_async(self, func, callback=None):
#     587     """Schedule a func to be run"""
# --> 588     future = self._workers.submit(func)
#     589     if callback is not None:
#     590         future.add_done_callback(callback)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/reusable_executor.py:225, in _ReusablePoolExecutor.submit(self, fn, *args, **kwargs)
#     223 def submit(self, fn, *args, **kwargs):
#     224     with self._submit_resize_lock:
# --> 225         return super().submit(fn, *args, **kwargs)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:1248, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#    1245 # Wake up queue management thread
#    1246 self._executor_manager_thread_wakeup.wakeup()
# -> 1248 self._ensure_executor_running()
#    1249 return f
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:1220, in ProcessPoolExecutor._ensure_executor_running(self)
#    1218 with self._processes_management_lock:
#    1219     if len(self._processes) != self._max_workers:
# -> 1220         self._adjust_process_count()
#    1221     self._start_executor_manager_thread()
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:1209, in ProcessPoolExecutor._adjust_process_count(self)
#    1207         p = self._context.Process(target=_process_worker, args=args)
#    1208     p._worker_exit_lock = worker_exit_lock
# -> 1209     p.start()
#    1210     self._processes[p.pid] = p
#    1211 mp.util.debug(
#    1212     f"Adjusted process count to {self._max_workers}: "
#    1213     f"{[(p.name, pid) for pid, p in self._processes.items()]}"
#    1214 )
#
# File ~/anaconda3/envs/mne/lib/python3.12/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/backend/process.py:45, in LokyProcess._Popen(process_obj)
#      43 else:
#      44     from .popen_loky_posix import Popen
# ---> 45 return Popen(process_obj)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/backend/popen_loky_posix.py:48, in Popen.__init__(self, process_obj)
#      46 self.returncode = None
#      47 self._fds = []
# ---> 48 self._launch(process_obj)
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/backend/popen_loky_posix.py:128, in Popen._launch(self, process_obj)
#     124     self.duplicate_for_child(mp_tracker_fd)
#     126 from .fork_exec import fork_exec
# --> 128 pid = fork_exec(cmd_python, self._fds, env=process_obj.env)
#     129 util.debug(
#     130     f"launched python with pid {pid} and cmd:\n{cmd_python}"
#     131 )
#     132 self.sentinel = parent_r
#
# File ~/anaconda3/envs/mne/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38, in fork_exec(cmd, keep_fds, env)
#      35 env = env or {}
#      36 child_env = {**os.environ, **env}
# ---> 38 pid = os.fork()
#      39 if pid == 0:  # pragma: no cover
#      40     close_fds(keep_fds)
#
# OSError: [Errno 12] Cannot allocate memory

# %%
u_hat = cdl.u_hat_ # spatial
v_hat = cdl.v_hat_ # temporal
z_hat = cdl.z_hat_ # scores
print(v_hat.shape)

for i in range(n_atoms):
    plt.figure(figsize=(4, 0.6))
    plt.plot(v_hat[i, :], 'k')
    plt.title(i)
plt.show()

MAT_FILE = filepath[33:37] + '_' + filepath[38:42] + '_BB_' + str(HI_PASS) + '-' + str(LOW_PASS) + 'Hz_' + str(n_atoms) + '_Atoms_' + str(ATOM_DURATION) + '(s).mat'
savemat('./mat_files/' + MAT_FILE, {"u_hat": u_hat, "v_hat": v_hat, 'z_hat': z_hat})
print(MAT_FILE)

# %%
#z_hat[0].shape
z_hat.shape[1]

# %%
for i in np.arange(z_hat.shape[1]):    
    plt.figure(figsize=(6, 2))
    plt.plot(z_hat[:, i, :].T, 'k', alpha=0.25) 
    plt.title(i)
    
plt.show()

# %%
values = u_hat.shape[9]
# axes should be a 2x2 numpy array
fig, axes = plt.subplots(figsize=(10,10), ncols=2, nrows=2)

# the actual plotting function. 
draw_four_views(axes, values, surf_parcel_names, brain_3d_surfaces, cmap=CMAP, norm_values=Z_LIM)
print(freq_bank[IDX], ' Hz')
